# %% [markdown]
# <div style="background: linear-gradient(135deg, #0072B2 0%, #004f7a 100%); color: white; padding: 48px 42px; border-radius: 14px; margin: 0 0 24px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica, sans-serif;"><div style="font-size: 11px; letter-spacing: 3px; text-transform: uppercase; opacity: 0.7; margin-bottom: 8px; font-weight: 500;">Cours en 6 heures</div><h1 style="margin: 0 0 4px 0; font-size: 38px; font-weight: 600; color: white; line-height: 1.15; border: none; padding: 0;">Analyse de Données avec Python pour Professionnels de la Santé</h1><div style="font-size: 17px; opacity: 0.92; margin-top: 14px; line-height: 1.5; max-width: 620px;">Une formation pratique en Python pour les professionnels de santé, épidémiologistes, et étudiants en santé publique. Six modules d'une heure, du Python de base au machine learning clinique.</div></div><h2 style="margin-top: 28px; font-size: 22px; color: #222;">Les six modules</h2><div style="border: 1px solid #e0e0e0; border-radius: 10px; padding: 22px 24px; margin-bottom: 14px; background: #fafbfc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;"><div style="display: flex; align-items: baseline; justify-content: space-between; margin-bottom: 10px;"><div><span style="background: #0072B2; color: white; padding: 4px 12px; border-radius: 12px; font-size: 12px; font-weight: 600; margin-right: 12px; letter-spacing: 0.8px;">MODULE 1</span><a href="module_01_python_pandas.ipynb" style="text-decoration: none; color: #004f7a; font-size: 19px; font-weight: 600;">Python et Pandas</a></div><div style="font-size: 12px; color: #888;">60 min</div></div><div style="color: #444; font-size: 14px; line-height: 1.55; margin-bottom: 12px;">Variables, listes, dictionnaires, fonctions, boucles. Charger un CSV public et l'inspecter. Filtrer, trier, grouper avec pandas. Le socle Python pour les cinq modules suivants.</div><div style="font-size: 12px; color: #666; margin-bottom: 12px;"><strong>Données :</strong> Gapminder  &middot;  <strong>Prerequis :</strong> Aucun</div><div><a href="module_01_python_pandas.ipynb" style="display: inline-block; background: #0072B2; color: white; padding: 7px 16px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; margin-right: 8px;">Ouvrir le notebook</a><a href="https://colab.research.google.com/github/gabayae/-python-sante/blob/main/notebooks_vierges/module_01_python_pandas.ipynb" target="_blank" style="display: inline-block; background: white; color: #0072B2; padding: 6px 15px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; border: 1px solid #0072B2;">Ouvrir dans Colab</a></div></div><div style="border: 1px solid #e0e0e0; border-radius: 10px; padding: 22px 24px; margin-bottom: 14px; background: #fafbfc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;"><div style="display: flex; align-items: baseline; justify-content: space-between; margin-bottom: 10px;"><div><span style="background: #0072B2; color: white; padding: 4px 12px; border-radius: 12px; font-size: 12px; font-weight: 600; margin-right: 12px; letter-spacing: 0.8px;">MODULE 2</span><a href="module_02_nettoyage_descriptif.ipynb" style="text-decoration: none; color: #004f7a; font-size: 19px; font-weight: 600;">Nettoyage et descriptif</a></div><div style="font-size: 12px; color: #888;">60 min</div></div><div style="color: #444; font-size: 14px; line-height: 1.55; margin-bottom: 12px;">Valeurs manquantes (MCAR, MAR, MNAR), pipeline de nettoyage reutilisable, validation par plages cliniques. Tendance centrale, dispersion. Mesures épidémiologiques cles : prévalence, incidence, RR, OR avec IC.</div><div style="font-size: 12px; color: #666; margin-bottom: 12px;"><strong>Données :</strong> Gapminder  &middot;  <strong>Prerequis :</strong> Module 1</div><div><a href="module_02_nettoyage_descriptif.ipynb" style="display: inline-block; background: #0072B2; color: white; padding: 7px 16px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; margin-right: 8px;">Ouvrir le notebook</a><a href="https://colab.research.google.com/github/gabayae/-python-sante/blob/main/notebooks_vierges/module_02_nettoyage_descriptif.ipynb" target="_blank" style="display: inline-block; background: white; color: #0072B2; padding: 6px 15px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; border: 1px solid #0072B2;">Ouvrir dans Colab</a></div></div><div style="border: 1px solid #e0e0e0; border-radius: 10px; padding: 22px 24px; margin-bottom: 14px; background: #fafbfc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;"><div style="display: flex; align-items: baseline; justify-content: space-between; margin-bottom: 10px;"><div><span style="background: #0072B2; color: white; padding: 4px 12px; border-radius: 12px; font-size: 12px; font-weight: 600; margin-right: 12px; letter-spacing: 0.8px;">MODULE 3</span><a href="module_03_visualisation.ipynb" style="text-decoration: none; color: #004f7a; font-size: 19px; font-weight: 600;">Visualisation</a></div><div style="font-size: 12px; color: #888;">60 min</div></div><div style="color: #444; font-size: 14px; line-height: 1.55; margin-bottom: 12px;">Histogramme, boîte a moustaches, barres, ligne, scatter, heatmap. Annoter avec axes, unites, seuils cliniques. Palette accessible aux daltoniens. Composer un tableau de bord 4 panneaux.</div><div style="font-size: 12px; color: #666; margin-bottom: 12px;"><strong>Données :</strong> Gapminder + simulations  &middot;  <strong>Prerequis :</strong> Module 1</div><div><a href="module_03_visualisation.ipynb" style="display: inline-block; background: #0072B2; color: white; padding: 7px 16px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; margin-right: 8px;">Ouvrir le notebook</a><a href="https://colab.research.google.com/github/gabayae/-python-sante/blob/main/notebooks_vierges/module_03_visualisation.ipynb" target="_blank" style="display: inline-block; background: white; color: #0072B2; padding: 6px 15px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; border: 1px solid #0072B2;">Ouvrir dans Colab</a></div></div><div style="border: 1px solid #e0e0e0; border-radius: 10px; padding: 22px 24px; margin-bottom: 14px; background: #fafbfc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;"><div style="display: flex; align-items: baseline; justify-content: space-between; margin-bottom: 10px;"><div><span style="background: #0072B2; color: white; padding: 4px 12px; border-radius: 12px; font-size: 12px; font-weight: 600; margin-right: 12px; letter-spacing: 0.8px;">MODULE 4</span><a href="module_04_tests_hypotheses.ipynb" style="text-decoration: none; color: #004f7a; font-size: 19px; font-weight: 600;">Tests d'hypothèses</a></div><div style="font-size: 12px; color: #888;">60 min</div></div><div style="color: #444; font-size: 14px; line-height: 1.55; margin-bottom: 12px;">t-test (un / deux échantillons / apparie), chi-deux, Mann-Whitney U. Choisir le bon test, vérifier les conditions, rapporter taille d'effet et IC. Correction pour tests multiples (Bonferroni, FDR).</div><div style="font-size: 12px; color: #666; margin-bottom: 12px;"><strong>Données :</strong> Framingham  &middot;  <strong>Prerequis :</strong> Modules 1, 2</div><div><a href="module_04_tests_hypotheses.ipynb" style="display: inline-block; background: #0072B2; color: white; padding: 7px 16px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; margin-right: 8px;">Ouvrir le notebook</a><a href="https://colab.research.google.com/github/gabayae/-python-sante/blob/main/notebooks_vierges/module_04_tests_hypotheses.ipynb" target="_blank" style="display: inline-block; background: white; color: #0072B2; padding: 6px 15px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; border: 1px solid #0072B2;">Ouvrir dans Colab</a></div></div><div style="border: 1px solid #e0e0e0; border-radius: 10px; padding: 22px 24px; margin-bottom: 14px; background: #fafbfc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;"><div style="display: flex; align-items: baseline; justify-content: space-between; margin-bottom: 10px;"><div><span style="background: #0072B2; color: white; padding: 4px 12px; border-radius: 12px; font-size: 12px; font-weight: 600; margin-right: 12px; letter-spacing: 0.8px;">MODULE 5</span><a href="module_05_regression.ipynb" style="text-decoration: none; color: #004f7a; font-size: 19px; font-weight: 600;">Regression</a></div><div style="font-size: 12px; color: #888;">60 min</div></div><div style="color: #444; font-size: 14px; line-height: 1.55; margin-bottom: 12px;">Regression linéaire simple et multiple avec statsmodels. Confounding et ajustement. Hypotheses OLS. Regression logistique et odds ratios. Sensibilite, spécificité, VPP, VPN.</div><div style="font-size: 12px; color: #666; margin-bottom: 12px;"><strong>Données :</strong> Pima Indians Diabetes  &middot;  <strong>Prerequis :</strong> Modules 1, 2, 4</div><div><a href="module_05_regression.ipynb" style="display: inline-block; background: #0072B2; color: white; padding: 7px 16px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; margin-right: 8px;">Ouvrir le notebook</a><a href="https://colab.research.google.com/github/gabayae/-python-sante/blob/main/notebooks_vierges/module_05_regression.ipynb" target="_blank" style="display: inline-block; background: white; color: #0072B2; padding: 6px 15px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; border: 1px solid #0072B2;">Ouvrir dans Colab</a></div></div><div style="border: 1px solid #e0e0e0; border-radius: 10px; padding: 22px 24px; margin-bottom: 14px; background: #fafbfc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;"><div style="display: flex; align-items: baseline; justify-content: space-between; margin-bottom: 10px;"><div><span style="background: #0072B2; color: white; padding: 4px 12px; border-radius: 12px; font-size: 12px; font-weight: 600; margin-right: 12px; letter-spacing: 0.8px;">MODULE 6</span><a href="module_06_ml_clinique.ipynb" style="text-decoration: none; color: #004f7a; font-size: 19px; font-weight: 600;">ML clinique</a></div><div style="font-size: 12px; color: #888;">60 min</div></div><div style="color: #444; font-size: 14px; line-height: 1.55; margin-bottom: 12px;">Train / test stratifie, validation croisee 5-folds. Arbres et forêts aléatoires avec scikit-learn. ROC + AUC, courbe de calibration, audit d'équité par sexe.</div><div style="font-size: 12px; color: #666; margin-bottom: 12px;"><strong>Données :</strong> UCI Heart Disease  &middot;  <strong>Prerequis :</strong> Modules 1, 2, 5</div><div><a href="module_06_ml_clinique.ipynb" style="display: inline-block; background: #0072B2; color: white; padding: 7px 16px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; margin-right: 8px;">Ouvrir le notebook</a><a href="https://colab.research.google.com/github/gabayae/-python-sante/blob/main/notebooks_vierges/module_06_ml_clinique.ipynb" target="_blank" style="display: inline-block; background: white; color: #0072B2; padding: 6px 15px; border-radius: 6px; text-decoration: none; font-size: 13px; font-weight: 500; border: 1px solid #0072B2;">Ouvrir dans Colab</a></div></div>

# %% [markdown]
# <h2 style="margin-top: 28px; font-size: 22px; color: #222;">Pour qui ?</h2><p style="line-height: 1.6; color: #444;">Ce cours est conçu pour les professionnels de santé (medecins, soignants, sage-femmes, pharmaciens), les épidémiologistes et les étudiants en santé publique qui veulent <strong>analyser leurs données eux-mêmes</strong>, sans avoir a sous-traiter chaque question a un statisticien.</p><p style="line-height: 1.6; color: #444;">Aucune expérience de programmation n'est requise pour démarrer le Module 1. Des notions de base en statistique (moyenne, IC) aident pour les Modules 4 a 6 mais ne sont pas obligatoires.</p>

# %% [markdown]
# <h2 style="margin-top: 28px; font-size: 22px; color: #222;">Demarrage rapide</h2><div style="display: grid; grid-template-columns: 1fr 1fr; gap: 16px; margin-top: 16px;"><div style="border: 1px solid #e0e0e0; border-radius: 8px; padding: 18px 22px; background: #fafbfc;"><div style="font-weight: 600; color: #004f7a; font-size: 15px; margin-bottom: 8px;">Option A — Google Colab</div><ol style="margin: 0; padding-left: 20px; color: #444; font-size: 13px; line-height: 1.7;"><li>Cliquer sur <strong>Ouvrir dans Colab</strong> du Module 1.</li><li>Executer les cellules avec <kbd>Maj + Entree</kbd>.</li><li>Aucune installation locale nécessaire.</li></ol></div><div style="border: 1px solid #e0e0e0; border-radius: 8px; padding: 18px 22px; background: #fafbfc;"><div style="font-weight: 600; color: #004f7a; font-size: 15px; margin-bottom: 8px;">Option B — Jupyter en local</div><ol style="margin: 0; padding-left: 20px; color: #444; font-size: 13px; line-height: 1.7;"><li>Installer <a href="https://www.anaconda.com/download" target="_blank" style="color: #0072B2;">Anaconda</a>.</li><li>Terminal : <code>cd 6hours</code> puis <code>jupyter notebook</code>.</li><li>Ouvrir <code>notebooks_vierges/module_01_python_pandas.ipynb</code>.</li></ol></div></div>

# %% [markdown]
# <h2 style="margin-top: 28px; font-size: 22px; color: #222;">Structure du dossier</h2><pre style="background: #f5f7f9; border: 1px solid #e0e0e0; border-radius: 6px; padding: 16px 20px; font-size: 13px; line-height: 1.55; color: #333; overflow-x: auto;">6hours/
# ├── README.md                       <span style="color:#888;"># installation, règles d'usage</span>
# ├── index.ipynb                     <span style="color:#888;"># <-- ce notebook (sommaire)</span>
# ├── data/                           <span style="color:#888;"># jeux de données mis en cache</span>
# ├── notebooks_vierges/              <span style="color:#888;"># a distribuer aux apprenants</span>
# │   ├── module_01_python_pandas.ipynb
# │   └── ...
# └── notebooks_executes/             <span style="color:#888;"># corriges, avec sorties</span>
#     ├── module_01_python_pandas.ipynb
#     └── ...
# </pre>

# %% [markdown]
# <div style="border-left: 4px solid #009E73; background: #f0f9f4; padding: 14px 18px; margin: 18px 0; border-radius: 0 6px 6px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;"><div style="font-weight: 600; color: #007a55; font-size: 11px; letter-spacing: 1.2px; margin-bottom: 6px;">COMMENT UTILISER CE DOSSIER</div><div style="color: #333; font-size: 14px; line-height: 1.5;">Les notebooks <strong>vierges</strong> et <strong>exécutés</strong> ont les mêmes cellules ; les vierges sont la version a distribuer aux apprenants (sorties effacees, ils executent eux-mêmes), les exécutés servent de corrige rapide pour l'instructeur. Reconstruire les vierges a partir des exécutés : <code>python _build/run_all.py</code>.</div></div>

# %% [markdown]
# <h2 style="margin-top: 28px; font-size: 22px; color: #222;">Pour aller plus loin</h2><p style="line-height: 1.7; color: #444;">Cette version 6 heures se concentre sur le coeur analytique. Les sujets suivants sont couverts dans la <strong>version longue 30 heures</strong> (dossier <code>../code/notebooks/</code> du depot) :</p><ul style="line-height: 1.8; color: #444;"><li><strong>Analyse temporelle</strong> — series épidémiques, décomposition saisonnière, COVID-19.</li><li><strong>Analyse spatiale</strong> — geopandas, choropleths, données Africa CDC / WHO.</li><li><strong>Projet capstone</strong> — analyse complete end-to-end, rapport, soutenance.</li></ul>

# %% [markdown]
# <hr style="margin: 40px 0 16px 0; border: none; border-top: 1px solid #e0e0e0;"><div style="text-align: center; color: #888; font-size: 12px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;">Materiel pedagogique libre. Si vous le reutilisez, citez la source.</div>
